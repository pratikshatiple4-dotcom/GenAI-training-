# %%
Data Loading First Step
From langchain-community.document -loaders import TextLoader
Loadder =TextLoader('pic.txt';encoding=''utf=8'')
Loadder
# Out:
#   Cell In[1], line 1
#     Data Loading First Step
#          ^
# SyntaxError: invalid syntax

# %%
Data Loading First Step
From langchain-community.document -loaders  import TextLoader
Loadder =TextLoader('pic.txt';encoding=''utf=8'')
Loadder
# Out:
#   Cell In[4], line 1
#     Data Loading First Step
#          ^
# SyntaxError: invalid syntax

# %%
Data Loading First Step
From langchain_community. documents_loading import TextLoader
